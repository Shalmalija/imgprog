# %%
import cv2 as cv

# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
print("OpenCV-Python Version %s" % cv2.__version__)
# Out:
# OpenCV-Python Version 4.1.0

# %%
img=cv2.imread('messi.jpg',cv2.IMREAD_COLOR)
if img is None:
    print('Open Error')
else:
    print( 'Image Loaded')
# Out:
# Image Loaded

# %%
print(type(img))
print img.shape
print img.dtype
print img[:2,:2,:]

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
print  (type(img))
print (img.shape)
print (img.dtype)
print (img[:2,:2,:])
# Out:
# <class 'numpy.ndarray'>
# (342, 548, 3)
# uint8
# [[[39 43 44]
#   [42 46 47]]
#
#  [[37 40 44]
#   [42 45 49]]]

# %%
img2=np.zeros((512,512,3), np.uint8)
plt.imshow(img2)

# %%
cv2.line(img2,(0,0),(511,511),(155,0,0),5) 

#.............intial point,last point,color,thickness
cv2
# Out:
# <module 'cv2.cv2' from 'C:\\Users\\user\\Anaconda3\\lib\\site-packages\\cv2\\cv2.cp37-win_amd64.pyd'>

# %%
plt.imshow(img2)

# %%
cv2.line(img2,(0,0),(511,511),(155,0,0),5) #line
cv2.rectangle(img2,(384,0),(510,128),(0,255,0),3) #rectangle
cv2.circle(img2,(447,63),63,(0,0,255),-1) #circle
plt.imshow(img2)

# %%
img[50,235]

# %%
for i in range(5):
    for j in range(5):
        img[50+i,235+j]=(0,255,0)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
for i in range(5):
    for j in range(5):
        img[290+i,450+j]=(0,0,255)#BGR
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#MAKING TWO BALLS
ball=img[280:340,330:390]
img[273:333,100:160]=ball
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
leg1=img[240:285,415:485]
img[240:285,115:185]=leg1
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
stud = img[250:290, 380:460]
img[250:290, 150:230] = stud
stud2 = img[301:333, 251:310]
img[301:333, 162:221] = stud2
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
cv2.circle(img2,(447,63),63,(0,0,255),-1)

# %%
cv2.line(img2,(447,63),63,(0,0,255),-1)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-30-e15010d815a5> in <module>
# ----> 1 cv2.line(img2,(447,63),63,(0,0,255),-1)
#
# SystemError: new style getargs format but argument is not a tuple
