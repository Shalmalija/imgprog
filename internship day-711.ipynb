# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
cd=pd.read_csv('Classified Data')

# %%
cd
# Out:
#      Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0             0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608
# 1             1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450
# 2             2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781
# 3             3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128
# 4             4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727
# 5             5  0.833928  1.523302  1.104743  1.021139  1.107377  1.010930
# 6             6  0.944705  1.251761  1.074885  0.286473  0.996440  0.428860
# 7             7  0.816174  1.088392  0.895343  0.243860  0.943123  1.045131
# 8             8  0.776551  1.463812  0.783825  0.337278  0.742215  1.072756
# 9             9  0.772280  0.515111  0.891596  0.940862  1.430568  0.885876
# 10           10  1.284999  1.331018  0.618910  0.657017  1.037191  0.717346
# ...

# %%
knn=pd.read_csv('KNN_Project_Data')

# %%
knn
# Out:
#             XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0    1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1    1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2    1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3    1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4    1018.340526  1313.679056   950.622661  724.742174   843.065903
# 5    1587.993461   667.420121  2072.048544  364.624958   905.011385
# 6    1497.293624   822.435853   908.059366  671.797517  1280.270442
# 7    1172.820769  1166.958461   455.656588  445.572745  1109.894585
# 8     839.494647  1089.747059   653.699894  659.334590  1529.725972
# 9    1028.689140   202.089774  1030.841860  429.109102   943.104815
# 10   1042.945431   826.009900   741.518594  548.237381  1528.675999
# 11    715.533949   768.001549  1513.342810   95.995876  1281.787242
# 12    747.291672   686.633284  1616.229550  511.187764  1134.462664
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler

# %%
scaled_features=scaler.transform
(knn.drop('TARGET CLASS',axis=1))
#scaler.fit(cd.drop('TARGET CLASS',axis=1))
# Out:
#             XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0    1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1    1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2    1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3    1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4    1018.340526  1313.679056   950.622661  724.742174   843.065903
# 5    1587.993461   667.420121  2072.048544  364.624958   905.011385
# 6    1497.293624   822.435853   908.059366  671.797517  1280.270442
# 7    1172.820769  1166.958461   455.656588  445.572745  1109.894585
# 8     839.494647  1089.747059   653.699894  659.334590  1529.725972
# 9    1028.689140   202.089774  1030.841860  429.109102   943.104815
# 10   1042.945431   826.009900   741.518594  548.237381  1528.675999
# 11    715.533949   768.001549  1513.342810   95.995876  1281.787242
# 12    747.291672   686.633284  1616.229550  511.187764  1134.462664
# ...

# %%
scaled_features=scaler.transform(cd.drop('TARGET CLASS',axis=1))
#scaler.fit(cd.drop('TARGET CLASS',axis=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-23f747014838> in <module>
# ----> 1 scaled_features=scaler.transform(cd.drop('TARGET CLASS',axis=1))
#       2 #scaler.fit(cd.drop('TARGET CLASS',axis=1))
#
# TypeError: transform() missing 1 required positional argument: 'X'

# %%
knn_feat=pd.DataFrame(scaled_features,columns=knn.columns[:-1])
knn_feat.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-964023af59ca> in <module>
# ----> 1 knn_feat=pd.DataFrame(scaled_features,columns=knn.columns[:-1])
#       2 knn_feat.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(scaled_features,cd['TARGET CLASS'],test_size=0.30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-8a8209ebf088> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test=train_test_split(scaled_features,cd['TARGET CLASS'],test_size=0.30)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     229     """
#     230
# ...

# %%
pred=knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-71c68aaea15d> in <module>
# ----> 1 pred=knn.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'predict'

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train,y_train)
pred=knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-afe3a4d5e348> in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 knn=KNeighborsClassifier(n_neighbors=1)
# ----> 3 knn.fit(x_train,y_train)
#       4 pred=knn.predict(x_test)
#
# NameError: name 'x_train' is not defined

# %%
for i in range(1,40):
    knn=KNeaighborsClassfier(n_neighbors=i)
    knn.fit(X_train,y_train)

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue',linestyle='dashed',marjer='o',marjerfacecolor='red',markersize=10)
plt.title("Error Rate vs. K value")
plt.xlabel('K')
plt.ylabel('Error Rate')
